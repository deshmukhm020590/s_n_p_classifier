# %% [markdown]
# # ============================================================
# # Author: Mayur Deshmukh
# # Name: 03_feature_engineer.ipynb
# # Project: ML-Binary-Classifier-For-Stock-Price-Prediction
# # Purpose: Feature Engineering for Prediction Model
# # Python Version: 3.11
# # ============================================================
